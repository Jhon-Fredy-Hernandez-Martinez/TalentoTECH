# %% [markdown]
# <a href="https://colab.research.google.com/github/Jhon-Fredy-Hernandez-Martinez/TalentoTECH/blob/main/Ejercicio%3ADataFrame.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# Crear nuevos datos
value_p_list = ['Gorras', 'Bufandas', 'Guantes', 'Calcetines', 'Sombreros', 'Mochilas', 'Sacos', 'Chalecos', 'Faldas', 'Pantalones']
value_uv_list = [28, 35, 45, 31, 20, 19, 21, 32, 33, 42]
value_in_list = [2100000, 1850000, 1300000, 1650000, 2700000, 1370000, 1240000, 1450000, 2820000, 2250000]

# Crear otro diccionario con los nuevos datos
data_dict = {
    "Producto": value_p_list,
    "Unidades vendidas": value_uv_list,
    "Ingresos": value_in_list
}

# Crear el DataFrame
df = pd.DataFrame(data_dict)

# Mostrar el DataFrame
print(df)
# Out:
#      Producto  Unidades vendidas  Ingresos
# 0      Gorras                 28   2100000
# 1    Bufandas                 35   1850000
# 2     Guantes                 45   1300000
# 3  Calcetines                 31   1650000
# 4   Sombreros                 20   2700000
# 5    Mochilas                 19   1370000
# 6       Sacos                 21   1240000
# 7    Chalecos                 32   1450000
# 8      Faldas                 33   2820000
# 9  Pantalones                 42   2250000

# %%
df.stats = df.describe()

df.stats
# Out:
# <ipython-input-5-dd9a512c8e4b>:1: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   df.stats = df.describe()
#        Unidades vendidas      Ingresos
# count          10.000000  1.000000e+01
# mean           30.600000  1.873000e+06
# std             8.884443  5.759639e+05
# min            19.000000  1.240000e+06
# 25%            22.750000  1.390000e+06
# 50%            31.500000  1.750000e+06
# 75%            34.500000  2.212500e+06
# max            45.000000  2.820000e+06
